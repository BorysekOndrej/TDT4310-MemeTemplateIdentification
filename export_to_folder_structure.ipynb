# %%
# https://www.tensorflow.org/tutorials/load_data/csv

import pandas as pd
from typing import List
import csv

dataset = pd.read_csv(
    "memes900k/captions_val.txt",
    delimiter="\t",
    quoting=csv.QUOTE_NONE, # this is neccesary, because the original input is misquoted
    names=["label", "score", "text"]
)
dataset.drop("score", axis="columns", inplace=True)
dataset

import csv

def output_to_file(path: str, dataset, columns: List[str], header: bool = False):
    df = dataset.copy(deep=True)
    df["label"] = df["label"].apply(lambda x: x[:28])
    df["label"] = df["label"].apply(lambda x: x.encode('ascii', 'ignore').decode('ascii'))
#     df.drop_duplicates(subset=columns[0], keep=False, inplace=True)
    df.to_csv(path, index=False, quoting=csv.QUOTE_ALL, columns=columns, header=header, encoding='ascii')
    
# output_to_file("captions_test_tag_universal_sep.csv", dataset, ["text", "label"], header=True)
dataset
# Out:
#                         label  \
# 0                      Y U No
# 1                      Y U No
# 2                      Y U No
# 3                      Y U No
# 4                      Y U No
# ...                       ...
# 74995  Bane Permission to Die
# 74996  Bane Permission to Die
# 74997  Bane Permission to Die
# 74998  Bane Permission to Die
# 74999  Bane Permission to Die
#
#                                                     text
# 0          commercial <sep> y u no same volume as show!?
# 1      TED <sep> y u no tell us how you met their mother
# 2                     INTERNET <sep> y u nO LET ME STUDY
# 3       Bad grades <sep> y u no smoke weed and get high?
# 4                         Green land <sep> Y U No Green?
# ...                                                  ...
# 74995  YOU THINK YOU KNOW PHYSIO <sep> I WAS BORN IN ...
# 74996  You didnt read the customs disclaimer <sep> Yo...
# 74997  you may deny my word when <sep> i give you per...
# 74998  ONLY WHEN I HAVE YOUR NUMBER <sep> I WILL BUY ...
# 74999  Leave facebook open on mordy's computer <sep> ...
#
# [75000 rows x 2 columns]

# %%
dataset = pd.read_csv(
    "captions_test_tag_universal_sep.csv",
    names=["text", "label"]
)
dataset
# Out:
#                                                     text  \
# 0               ADV ADV NOUN SEP NOUN VERB DET NOUN NOUN
# 1                    NOUN SEP NOUN NOUN NOUN NOUN NOUN .
# 2                     NOUN SEP NOUN NOUN NOUN NOUN . . .
# 3      PRON VERB . DET PRON NOUN SEP NOUN NOUN NOUN V...
# 4           NOUN SEP NOUN ADJ DET NOUN VERB ADJ VERB . .
# ...                                                  ...
# 74600  ADV NOUN PRT NOUN VERB NOUN SEP ADV PRON VERB ...
# 74601  NOUN NOUN . PRON VERB PRON SEP CONJ PRON VERB ...
# 74602                     NOUN NOUN VERB . SEP ADV ADJ .
# 74603  ADV NOUN VERB NOUN SEP PRON VERB PRON NOUN PRT...
# 74604     PRON VERB PRON NOUN PRT VERB SEP ADJ NOUN NOUN
#
#                         label
# 0                      Y U No
# 1                      Y U No
# 2                      Y U No
# 3                      Y U No
# 4                      Y U No
# ...                       ...
# 74600  Bane Permission to Die
# 74601  Bane Permission to Die
# 74602  Bane Permission to Die
# 74603  Bane Permission to Die
# 74604  Bane Permission to Die
#
# [74605 rows x 2 columns]

# %%
labels = list(set(dataset.label.tolist()))
# labels = [x.replace(" ", "_").encode('ascii', 'ignore').decode('ascii') for x in labels]
labels[:5]
# Out:
# ['Anti Joke Chicken',
#  'gordo granudo',
#  'Chill Out Lemur',
#  'American Pride Eagle',
#  'Stoner Stanley']

# %%
import pathlib

folder_paths = {}

for label in labels:
    folder_name = label.replace(" ", "_").encode('ascii', 'ignore').decode('ascii')
    folder_name = ''.join(x for x in folder_name if x.isalpha() or x == "_")
    folder_paths[label] = folder_name

# %%
folder_paths
# Out:
# {'Anti Joke Chicken': 'Anti_Joke_Chicken',
#  'gordo granudo': 'gordo_granudo',
#  'Chill Out Lemur': 'Chill_Out_Lemur',
#  'American Pride Eagle': 'American_Pride_Eagle',
#  'Stoner Stanley': 'Stoner_Stanley',
#  'obama laughing ': 'obama_laughing_',
#  'say what one more time': 'say_what_one_more_time',
#  'Donald Trump': 'Donald_Trump',
#  'Futurama Fry': 'Futurama_Fry',
#  'Overly Attached Girlfriend': 'Overly_Attached_Girlfriend',
#  'skyrim stan': 'skyrim_stan',
#  'Retail Robin': 'Retail_Robin',
#  'mens wearhouse': 'mens_wearhouse',
#  'That escalated quickly-Ron B': 'That_escalated_quicklyRon_B',
#  'RomneyMakes.com': 'RomneyMakescom',
#  'dolan meme': 'dolan_meme',
#  'Nio Malvado - Evil Toddler': 'Nio_Malvado__Evil_Toddler',
#  'dr. evil quotation marks': 'dr_evil_quotation_marks',
#  'you mean to tell me black ki': 'you_mean_to_tell_me_black_ki',
#  'Sunny Student': 'Sunny_Student',
#  "I don't always guy meme": 'I_dont_always_guy_meme',
#  'Technologically Impaired Duc': 'Technologically_Impaired_Duc',
#  "And it's gone": 'And_its_gone',
#  'Oprah You get a': 'Oprah_You_get_a',
#  'Chronic Illness Cat': 'Chronic_Illness_Cat',
#  'Socially Awkward to Awesome ': 'Socially_Awkward_to_Awesome_',
#  'Rich Men Laughing': 'Rich_Men_Laughing',
#  'iHate': 'iHate',
#  'Internet Husband': 'Internet_Husband',
#  'katt williams shocked': 'katt_williams_shocked',
#  'Slowpoke': 'Slowpoke',
#  'Buddy the Elf': 'Buddy_the_Elf',
#  'ancient alien guy': 'ancient_alien_guy',
#  'Crazy Camel lol': 'Crazy_Camel_lol',
#  'KD you the real mvp f': 'KD_you_the_real_mvp_f',
#  'Tobey_Maguire': 'Tobey_Maguire',
#  'Carl Spackler': 'Carl_Spackler',
#  'Socially Awkward Penguin': 'Socially_Awkward_Penguin',
#  'Chemistry Cat': 'Chemistry_Cat',
#  'SouthPark Bad Time meme': 'SouthPark_Bad_Time_meme',
#  'Grumpy cat good': 'Grumpy_cat_good',
#  'Buzz lightyear meme fixd': 'Buzz_lightyear_meme_fixd',
#  'Serious Kip': 'Serious_Kip',
#  'Conspiracy Keanu': 'Conspiracy_Keanu',
#  'Stupid Monkey': 'Stupid_Monkey',
#  'Keep calm and': 'Keep_calm_and',
#  'flniuydl': 'flniuydl',
#  'First World Problems': 'First_World_Problems',
#  'Idiot Nerd Girl': 'Idiot_Nerd_Girl',
#  "Timmy turner's dad IF I HAD ": 'Timmy_turners_dad_IF_I_HAD_',
#  'if you know what': 'if_you_know_what',
#  'Why the fuck': 'Why_the_fuck',
#  'You were the chosen one ': 'You_were_the_chosen_one_',
#  'Blackjack and hookers bender': 'Blackjack_and_hookers_bender',
#  'spongebob rainbow': 'spongebob_rainbow',
#  'Anchorman Birthday': 'Anchorman_Birthday',
#  'batman slap robin': 'batman_slap_robin',
#  'Bill Murray Caddyshack': 'Bill_Murray_Caddyshack',
#  'Pennywise the Clown': 'Pennywise_the_Clown',
#  'Nick Cage': 'Nick_Cage',
#  'Obama': 'Obama',
#  'Shirtless Ryan Gosling': 'Shirtless_Ryan_Gosling',
#  'Fat Guy': 'Fat_Guy',
#  'so i guess you could say thi': 'so_i_guess_you_could_say_thi',
#  'Jealous Girl': 'Jealous_Girl',
#  'Ryan Gosling Hey ': 'Ryan_Gosling_Hey_',
#  'GUESS WHO YOU': 'GUESS_WHO_YOU',
#  'Picard facepalm ': 'Picard_facepalm_',
#  'Bear Grylls Loneliness': 'Bear_Grylls_Loneliness',
#  'Mafia Baby': 'Mafia_Baby',
#  'Yes, this is dog!': 'Yes_this_is_dog',
#  'Dr. Evil and His Minions': 'Dr_Evil_and_His_Minions',
#  'Bad Luck Brian': 'Bad_Luck_Brian',
#  'Captain Picard': 'Captain_Picard',
#  'Y U SO': 'Y_U_SO',
#  'kill yourself guy': 'kill_yourself_guy',
#  'Dolan duck': 'Dolan_duck',
#  'Diagnostic House': 'Diagnostic_House',
#  'I will find you and kill you': 'I_will_find_you_and_kill_you',
#  'Dogeeeee': 'Dogeeeee',
#  'Funes 20 aos': 'Funes__aos',
#  'Sudden Realization Ralph': 'Sudden_Realization_Ralph',
#  'The Godfather': 'The_Godfather',
#  'Sassy Black Woman': 'Sassy_Black_Woman',
#  'Lame Pun Coon': 'Lame_Pun_Coon',
#  'Unlucky Brian Strikes Again': 'Unlucky_Brian_Strikes_Again',
#  'You shall not pass': 'You_shall_not_pass',
#  'Pepperidge Farm Remembers FG': 'Pepperidge_Farm_Remembers_FG',
#  'Douchebag Roommate': 'Douchebag_Roommate',
#  'Bad Factman': 'Bad_Factman',
#  'I double dare you': 'I_double_dare_you',
#  'Matrix Morpheus': 'Matrix_Morpheus',
#  'Unimpressed Queen': 'Unimpressed_Queen',
#  'Hipster Ariel': 'Hipster_Ariel',
#  'Cool Dog': 'Cool_Dog',
#  'Pulp Fiction': 'Pulp_Fiction',
#  'Socially Awesome Awkward Pen': 'Socially_Awesome_Awkward_Pen',
#  'Science Cat': 'Science_Cat',
#  'storytime jesus': 'storytime_jesus',
#  'Skeptical african kid ': 'Skeptical_african_kid_',
#  'Bear Grylls': 'Bear_Grylls',
#  'Disaster Girl': 'Disaster_Girl',
#  'Chuck Norris ': 'Chuck_Norris_',
#  'Kermit The Frog Drinking Tea': 'Kermit_The_Frog_Drinking_Tea',
#  'So Then I Said...': 'So_Then_I_Said',
#  "I don't know who you are...": 'I_dont_know_who_you_are',
#  'Fallout 3': 'Fallout_',
#  'Trologirl': 'Trologirl',
#  'Good Guy Greg': 'Good_Guy_Greg',
#  'Prepare yourself': 'Prepare_yourself',
#  'Never Have I Been So Wrong': 'Never_Have_I_Been_So_Wrong',
#  'Angry Black Woman': 'Angry_Black_Woman',
#  'men in black': 'men_in_black',
#  'Challenge Accepted 2': 'Challenge_Accepted_',
#  'Skeptical 3rd World Kid': 'Skeptical_rd_World_Kid',
#  'Chuck Norris Advice': 'Chuck_Norris_Advice',
#  'Paranoid Parrot': 'Paranoid_Parrot',
#  'God': 'God',
#  "I have no idea what I'm doin": 'I_have_no_idea_what_Im_doin',
#  'I will Find You Meme': 'I_will_Find_You_Meme',
#  'Bane Meme': 'Bane_Meme',
#  'Gangnam Style': 'Gangnam_Style',
#  'evil plan kid': 'evil_plan_kid',
#  'Successful Mexican': 'Successful_Mexican',
#  'Batman Bitchslap': 'Batman_Bitchslap',
#  'Pushing Patrick': 'Pushing_Patrick',
#  'Hipster Kitty': 'Hipster_Kitty',
#  'drunk baby 1': 'drunk_baby_',
#  'Craig would be so happy': 'Craig_would_be_so_happy',
#  'Anxiety Cat': 'Anxiety_Cat',
#  'Archer': 'Archer',
#  'bender blackjack and hookers': 'bender_blackjack_and_hookers',
#  'look-marge': 'lookmarge',
#  'Computer kid': 'Computer_kid',
#  'High Expectations Asian Fath': 'High_Expectations_Asian_Fath',
#  'skeptical black kid': 'skeptical_black_kid',
#  'i should buy a boat cat': 'i_should_buy_a_boat_cat',
#  "Bill O'Reilly Proves God": 'Bill_OReilly_Proves_God',
#  'aysi': 'aysi',
#  'You keep using that word, I ': 'You_keep_using_that_word_I_',
#  'Correction Man ': 'Correction_Man_',
#  'FPS N00b': 'FPS_Nb',
#  'Grumpy Cat 2': 'Grumpy_Cat_',
#  'Joseph Ducreux': 'Joseph_Ducreux',
#  'Okay Guy': 'Okay_Guy',
#  'Ash Pedreiro': 'Ash_Pedreiro',
#  'Advice Dog': 'Advice_Dog',
#  "south park aand it's gone": 'south_park_aand_its_gone',
#  'Vengeance Dad': 'Vengeance_Dad',
#  'Angry Arnold': 'Angry_Arnold',
#  'Dr Evil meme': 'Dr_Evil_meme',
#  "you don't say meme": 'you_dont_say_meme',
#  'That would be great': 'That_would_be_great',
#  'Sad Trooper': 'Sad_Trooper',
#  'fat chinese kid': 'fat_chinese_kid',
#  'you have no power here': 'you_have_no_power_here',
#  'Thespian Peacock': 'Thespian_Peacock',
#  'Depression Dog': 'Depression_Dog',
#  'Bad Advice Cat': 'Bad_Advice_Cat',
#  'Angry Cat Meme': 'Angry_Cat_Meme',
#  'Crying face': 'Crying_face',
#  'Pedobear': 'Pedobear',
#  'kill yourself guy blank': 'kill_yourself_guy_blank',
#  'Annoying Facebook Girl': 'Annoying_Facebook_Girl',
#  'went full retard': 'went_full_retard',
#  'Rage FU': 'Rage_FU',
#  'buddy jesus': 'buddy_jesus',
#  'McKayla Maroney Not Impresse': 'McKayla_Maroney_Not_Impresse',
#  'What If I Told You': 'What_If_I_Told_You',
#  'Foul Bachelorette Frog': 'Foul_Bachelorette_Frog',
#  'Roleplaying Rabbit': 'Roleplaying_Rabbit',
#  'Pawn Stars Rick': 'Pawn_Stars_Rick',
#  'Forever Alone': 'Forever_Alone',
#  'Yo Dawg': 'Yo_Dawg',
#  'Angry Linus': 'Angry_Linus',
#  "Why Can't I Hold All These?!": 'Why_Cant_I_Hold_All_These',
#  'evil toddler kid2': 'evil_toddler_kid',
#  'Steve Jobs Says': 'Steve_Jobs_Says',
#  'Asinine America': 'Asinine_America',
#  'pleaseguy ': 'pleaseguy_',
#  'Really Stoned Guy': 'Really_Stoned_Guy',
#  'sparta': 'sparta',
#  'Successful Black Man': 'Successful_Black_Man',
#  'One Does Not Simply': 'One_Does_Not_Simply',
#  'First Day on the internet ki': 'First_Day_on_the_internet_ki',
#  "Don't you, Squidward?": 'Dont_you_Squidward',
#  'x all the y': 'x_all_the_y',
#  'Black Kid': 'Black_Kid',
#  'Scumbag Steve': 'Scumbag_Steve',
#  'Generic Indian Guy': 'Generic_Indian_Guy',
#  'sad bear': 'sad_bear',
#  'Musically Oblivious 8th Grad': 'Musically_Oblivious_th_Grad',
#  'Kermit the frog': 'Kermit_the_frog',
#  'Skeptical third-world kid': 'Skeptical_thirdworld_kid',
#  'Socially Awesome Penguin': 'Socially_Awesome_Penguin',
#  'I can haz': 'I_can_haz',
#  'MR bean': 'MR_bean',
#  'Annoying Gamer Kid': 'Annoying_Gamer_Kid',
#  'Insanity Wolf': 'Insanity_Wolf',
#  'san juan cholo': 'san_juan_cholo',
#  'FU*CK THAT GUY': 'FUCK_THAT_GUY',
#  'All the things': 'All_the_things',
#  'your country needs you': 'your_country_needs_you',
#  'Overly Obsessed Girlfriend': 'Overly_Obsessed_Girlfriend',
#  'nerdy kid lolz': 'nerdy_kid_lolz',
#  'calamardo me vale': 'calamardo_me_vale',
#  'crying peter parker': 'crying_peter_parker',
#  'Pawn Stars': 'Pawn_Stars',
#  'Guess who ?': 'Guess_who_',
#  'Look at All the Fucks I Give': 'Look_at_All_the_Fucks_I_Give',
#  'Minecraft Guy': 'Minecraft_Guy',
#  'Ryan Gosling Hey Girl 3': 'Ryan_Gosling_Hey_Girl_',
#  'Laughing Girls ': 'Laughing_Girls_',
#  'NFL Ref Meeting': 'NFL_Ref_Meeting',
#  'Dancing black kid': 'Dancing_black_kid',
#  'mean girls': 'mean_girls',
#  "So You're Telling me": 'So_Youre_Telling_me',
#  'high/drunk guy': 'highdrunk_guy',
#  'Patrick Stewart WTF': 'Patrick_Stewart_WTF',
#  'so doge': 'so_doge',
#  'Philosoraptor': 'Philosoraptor',
#  'Professor Oak': 'Professor_Oak',
#  'really high guy': 'really_high_guy',
#  'Courage Wolf': 'Courage_Wolf',
#  'Not today arya': 'Not_today_arya',
#  'In Soviet Russia': 'In_Soviet_Russia',
#  'Whyyy???': 'Whyyy',
#  'Confused Bill Cosby ': 'Confused_Bill_Cosby_',
#  'Provincial Man': 'Provincial_Man',
#  'Uncle Dolan': 'Uncle_Dolan',
#  'newspaper cat realization': 'newspaper_cat_realization',
#  'Stalin Says': 'Stalin_Says',
#  'african kids dancing': 'african_kids_dancing',
#  'obama beer': 'obama_beer',
#  'Thats a paddlin': 'Thats_a_paddlin',
#  'Blank Black': 'Blank_Black',
#  'Pokemon Logic ': 'Pokemon_Logic_',
#  'Success Kid': 'Success_Kid',
#  'Liberal Douche Garofalo': 'Liberal_Douche_Garofalo',
#  'burning house girl': 'burning_house_girl',
#  'Skeptical African Child': 'Skeptical_African_Child',
#  'Ridiculously Photogenic Meta': 'Ridiculously_Photogenic_Meta',
#  'Racist Dog': 'Racist_Dog',
#  'Foul Bachelor Frog': 'Foul_Bachelor_Frog',
#  'Grumpy Cat Santa Hat': 'Grumpy_Cat_Santa_Hat',
#  'overly attached girl': 'overly_attached_girl',
#  'Homer retard': 'Homer_retard',
#  'Maury Lie Detector': 'Maury_Lie_Detector',
#  'Butthurt Dweller': 'Butthurt_Dweller',
#  'Office Space Boss': 'Office_Space_Boss',
#  'Winter is Coming': 'Winter_is_Coming',
#  'Imagination': 'Imagination',
#  'yaowonkaxd': 'yaowonkaxd',
#  'teacher': 'teacher',
#  'old lady': 'old_lady',
#  'evil raccoon': 'evil_raccoon',
#  'The Most Interesting Man In ': 'The_Most_Interesting_Man_In_',
#  'Scumbag God': 'Scumbag_God',
#  "Koala can't believe it": 'Koala_cant_believe_it',
#  'What if I told you / Matrix ': 'What_if_I_told_you__Matrix_',
#  'crying girl sad': 'crying_girl_sad',
#  'So I got that going on for m': 'So_I_got_that_going_on_for_m',
#  'african children dancing': 'african_children_dancing',
#  'Unpopular Opinion Puffin': 'Unpopular_Opinion_Puffin',
#  'My Precious Gollum': 'My_Precious_Gollum',
#  'Justin Bieber': 'Justin_Bieber',
#  'overly manlyman': 'overly_manlyman',
#  '1889 [10] guy': '__guy',
#  'Angry School Boy': 'Angry_School_Boy',
#  'Willy Wonka': 'Willy_Wonka',
#  'Desk Flip Rage Guy': 'Desk_Flip_Rage_Guy',
#  'Trollface': 'Trollface',
#  'Stoner Dog': 'Stoner_Dog',
#  'Fat Girl': 'Fat_Girl',
#  'Advice Yoda Gives': 'Advice_Yoda_Gives',
#  'Tough Spongebob': 'Tough_Spongebob',
#  'Business Cat': 'Business_Cat',
#  'Minecraft Creeper': 'Minecraft_Creeper',
#  'Art Student Owl': 'Art_Student_Owl',
#  'journalist': 'journalist',
#  'Correction Guy': 'Correction_Guy',
#  'Beavis and butthead': 'Beavis_and_butthead',
#  'Age Of Empires': 'Age_Of_Empires',
#  "You're gonna have a bad time": 'Youre_gonna_have_a_bad_time',
#  'dogeee': 'dogeee',
#  'Bane Permission to Die': 'Bane_Permission_to_Die',
#  'Advice Hitler': 'Advice_Hitler',
#  'Batman Slappp': 'Batman_Slappp',
#  'Not sure if troll': 'Not_sure_if_troll',
#  'Everywhere': 'Everywhere',
#  'Racist Dawg': 'Racist_Dawg',
#  'Yeah If You Could Just': 'Yeah_If_You_Could_Just',
#  'Spock': 'Spock',
#  'PTSD Karate Kyle': 'PTSD_Karate_Kyle',
#  'joker mind loss': 'joker_mind_loss',
#  'Ye Old Englishman': 'Ye_Old_Englishman',
#  'Grumpy Cat ': 'Grumpy_Cat_',
#  'Awkward Seal': 'Awkward_Seal',
#  'Y U No': 'Y_U_No',
#  'Bane': 'Bane'}

# %%
from sklearn.model_selection import train_test_split

train, test = train_test_split(dataset, test_size=0.2)
train
# Out:
#                                                     text  \
# 74050   NOUN NOUN NOUN NOUN SEP NOUN NOUN NOUN NOUN NOUN
# 55474             NOUN PRT ADV VERB . SEP PRON VERB VERB
# 63630  PRON VERB NOUN NOUN NOUN NOUN NOUN NOUN NOUN ....
# 23946  NOUN NOUN VERB DET ADJ ADJ NOUN SEP DET NOUN V...
# 67995           NOUN SEP VERB ADV VERB NOUN PRT ADP NOUN
# ...                                                  ...
# 60056                             NOUN VERB SEP . NOUN .
# 20051             ADV ADJ ADP VERB SEP CONJ VERB ADV ADJ
# 1776                      NOUN ADP ADJ NOUN SEP ADV VERB
# 31579  PRON VERB ADP NOUN SEP PRON VERB ADV ADV NOUN ...
# 44816  NOUN PRT VERB DET NOUN ADP PRON SEP PRON VERB ...
#
#                           label
# 74050              men in black
# 55474                 Nick Cage
# 63630            Not today arya
# 23946  Unpopular Opinion Puffin
# 67995      Grumpy Cat Santa Hat
# ...                         ...
# 60056  dr. evil quotation marks
# 20051         Not sure if troll
# 1776       First World Problems
# 31579             Hipster Ariel
# 44816           Idiot Nerd Girl
#
# [59684 rows x 2 columns]

# %%
from tqdm import tqdm
import shutil


def output_rows_to_folders(path_prefix: str, df):
    pathlib.Path(path_prefix).mkdir(parents=True, exist_ok=True)
    shutil.rmtree(path_prefix)

    for index, row in tqdm(df.iterrows()):
        text = row["text"]
        label = row["label"]

        folder_path = path_prefix + "/" + folder_paths[label]
        file_path = folder_path +"/"+ str(index).zfill(3)+".txt"

        pathlib.Path(folder_path).mkdir(parents=True, exist_ok=True)

        with open(file_path, "w", encoding="utf8") as f:
            f.write(text)

# %%
# output_rows_to_folders("custom_dataset/train", train)
# output_rows_to_folders("custom_dataset/test", test)
output_rows_to_folders("pos_dataset/train", train)
output_rows_to_folders("pos_dataset/test", test)
# Out:
# 59684it [00:33, 1755.51it/s]
# 14921it [00:08, 1679.40it/s]

# %%
# import tarfile
# import os.path

# def make_tarfile(output_filename, source_dir):
#     with tarfile.open(output_filename, "w:gz") as tar:
#         tar.add(source_dir, arcname=os.path.basename(source_dir))
        
# make_tarfile("custom_dataset.tar.gz", "custom_dataset")
